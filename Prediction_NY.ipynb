# %%
import pyodbc
import pandas as pd
import config as cfg

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cnxn = pyodbc.connect( 'DRIVER={ODBC Driver 13 for SQL Server};SERVER=' + cfg.mssql['server'] + ';DATABASE=' 
                      + cfg.mssql['database'] + ';UID=' + cfg.mssql['username'] + ';PWD=' + cfg.mssql['password'] )

# %%
query = "SELECT * FROM BankView WHERE [State]='NY';"
data = pd.read_sql(query, cnxn, index_col='BankID')
data.head()
# Out:
#        UniqueNum                                   Name  \
# BankID
# 6509      590864             Ballston Spa National Bank
# 6510      580447             Ballston Spa National Bank
# 6511        4660  Bank of America, National Association
# 6512      213160  Bank of America, National Association
# 6513      214981  Bank of America, National Association
#
#                         Address1 Address2    City State    Zip    Deposit  \
# BankID
# 6509            1973 Western Ave           Albany    NY  12203    1917000
# 6510    1207 Troy Schenectady Rd           Latham    NY  12110    3875000
# 6511             69 State Street           Albany    NY  12201  435463000
# 6512         1450 Western Avenue           Albany    NY  12203   97728000
# 6513         1791 Western Avenue           Albany    NY  12203   62203000
#
#             Lat      Lng      ...        ClosestPSDistance  MeanPSDistance  \
# BankID                        ...
# 6509    42.6950 -73.8794      ...                 3.261850        7.330062
# 6510    42.7725 -73.8230      ...                 2.947765        6.917659
# 6511    42.6499 -73.7522      ...                 0.986112        5.144061
# 6512    42.6808 -73.8373      ...                 4.095179        7.046373
# 6513    42.6905 -73.8662      ...                 3.999549        7.621675
#
#         PSCount    Take  PDistance  Officers1000  FFLCount  Target Population  \
# BankID
# 6509         11     958   0.373815      1.093750         8    None    98617.0
# 6510         14    1937   0.405223      1.425641         8    None        NaN
# 6511          9  217731   0.601389      2.820146         5    None    98617.0
# 6512         12   48864   0.290482      2.341346        10    None    98617.0
# 6513         13   31101   0.300045      1.318182        10    None    98617.0
#
#         CrimeRate1000
# BankID
# 6509        43.744993
# 6510              NaN
# 6511        43.744993
# 6512        43.744993
# 6513        43.744993
#
# [5 rows x 21 columns]

# %%
data['CrimeRate1000'].mean()
# Out:
# 29.42786864578506

# %%
data['Population'].mean()
# Out:
# 3629207.8229166665

# %%
data.isnull().sum()
# Out:
# UniqueNum               0
# Name                    0
# Address1                0
# Address2                0
# City                    0
# State                   0
# Zip                     0
# Deposit                 0
# Lat                     9
# Lng                     9
# ClosestStationID      233
# ClosestPSDistance       0
# MeanPSDistance          0
# PSCount                 0
# Take                    0
# PDistance               0
# Officers1000            0
# FFLCount                0
# Target               5033
# Population           3401
# CrimeRate1000        3401
# dtype: int64

# %%
values = {'CrimeRate1000': data['CrimeRate1000'].mean(), 'Population': data['Population'].mean()}
data.fillna(value=values, inplace=True)
data.shape
# Out:
# (5033, 21)

# %% [markdown]
# ## Use Model to Predict banks to Target

# %%
try:
    import cPickle as pickle
except ImportError:
    import pickle
    
## Load Model
model_filepath = 'targetbanks_randomforestclassifier.pkl'
in_logreg = open(model_filepath, 'rb')
rfc = pickle.load(in_logreg)
in_logreg.close()

# %%
feature_cols = ['ClosestPSDistance', 'Take', 'PDistance', 'Officers1000',
       'FFLCount', 'Population', 'CrimeRate1000']
X = data[feature_cols]
data['y_pred'] = rfc.predict(X)

# %%
# Total TARGETABLE banks
tgtsum = data[data.y_pred == 1].Name.count();
total = data.Name.count()
print(tgtsum, 'out of', total, ' pct:', round((tgtsum/total * 100)), '%')
# Out:
# 1953 out of 5033  pct: 39.0 %

# %% [markdown]
# ## Show Result

# %%
dftarget = data[data.y_pred == 1]
dftarget.drop(['UniqueNum', 
       'Deposit', 'Lat', 'Lng', 'ClosestStationID',
       'MeanPSDistance', 'PSCount', 'Target', 'Population'], axis=1, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ## Top 10 banks with highest Take

# %%
# Top 10 banks with highest Take
dftop10 = dftarget.sort_values(by=['Take'], ascending=[False]).head(10)
dftop10
# Out:
#                                              Name  \
# BankID
# 8936    JPMorgan Chase Bank, National Association
# 8850          HSBC Bank USA, National Association
# 8934    JPMorgan Chase Bank, National Association
# 8639        Bank of America, National Association
# 8768               Citibank, National Association
# 8652                                Bank of China
# 8927    JPMorgan Chase Bank, National Association
# 9209       Wells Fargo Bank, National Association
# 8817                          First Republic Bank
# 8684            Capital One, National Association
#
#                                 Address1 Address2      City State    Zip  \
# BankID
# 8936                  401 Madison Avenue           New York    NY  10017
# 8850                    452 Fifth Avenue           New York    NY  10018
# 8934                  401 Madison Avenue           New York    NY  10017
# 8639                115 West 42nd Street           New York    NY  10036
# 8768                     399 Park Avenue           New York    NY  10022
# 8652         1045 Avenue Of The Americas           New York    NY  10018
# 8927    349 Fifth Avenue And 34th Street           New York    NY  10016
# 9209                  437 Madison Avenue           New York    NY  10022
# 8817         1230 Avenue Of The Americas           New York    NY  10020
# 8684                 57 West 57th Street           New York    NY  10019
#
#         ClosestPSDistance       Take  PDistance  Officers1000  FFLCount  \
# BankID
# 8936             3.320694  174260736   0.367931           5.0        10
# 8850             2.940012   43650604   0.405999           5.0        10
# 8934             3.320694   33282569   0.367931           5.0        10
# 8639             3.113936   22024089   0.388606           5.0         9
# 8768             3.602696   12862500   0.339730           5.0        10
# 8652             2.969544   11522011   0.403046           5.0         9
# 8927             2.658231    7820909   0.434177           5.0        10
# 9209             3.422193    7128784   0.357781           5.0        10
# 8817             3.401485    4617530   0.359852           5.0        10
# 8684             3.822906    4485512   0.317709           5.0        10
#
#         CrimeRate1000  y_pred
# BankID
# 8936        20.357615       1
# 8850        20.357615       1
# 8934        20.357615       1
# 8639        20.357615       1
# 8768        20.357615       1
# 8652        20.357615       1
# 8927        20.357615       1
# 9209        20.357615       1
# 8817        20.357615       1
# 8684        20.357615       1

# %% [markdown]
# ## Top 10 of banks with highest distance to Police Station

# %%
# Top 10 of banks with highest distance to Police Station
dftop10 = dftarget.sort_values(by=['ClosestPSDistance'], ascending=False).head(10)
dftop10
# Out:
#                                              Name                   Address1  \
# BankID
# 7027               NBT Bank, National Association           147 Maple Avenue
# 10654           Capital One, National Association                160 Main St
# 10998                                   Jeff Bank        4864 State Route 52
# 10790   JPMorgan Chase Bank, National Association     645 William Floyd Pkwy
# 10796   JPMorgan Chase Bank, National Association        595 Sunrise Highway
# 7043                            Bank of Millbrook       3263 Franklin Avenue
# 10213                             Northfield Bank            6420 Amboy Road
# 10643           Capital One, National Association  300 South Wellwood Avenue
# 7028               NBT Bank, National Association            723 Main Street
# 10678              Citibank, National Association      1198 Deer Park Avenue
#
#        Address2            City State    Zip  ClosestPSDistance    Take  \
# BankID
# 7027                     Hobart    NY  13788               10.5   35472
# 10654                  Sayville    NY  11782               10.5   60248
# 10998            Jeffersonville    NY  12748               10.5   51408
# 10790                   Shirley    NY  11967               10.5   50691
# 10796              West Babylon    NY  11704               10.5  112956
# 7043                  Millbrook    NY  12545               10.5   57029
# 10213             Staten Island    NY  10309               10.5   44638
# 10643               Lindenhurst    NY  11757               10.5   50006
# 7028              Margaretville    NY  12455               10.5   50372
# 10678             North Babylon    NY  11703               10.5   83000
#
#         PDistance  Officers1000  FFLCount  CrimeRate1000  y_pred
# BankID
# 7027          0.0           0.0         2      29.427869       1
# 10654         0.0           0.0         5      29.427869       1
# 10998         0.0           0.0         4      29.427869       1
# 10790         0.0           0.0         1      29.427869       1
# 10796         0.0           0.0         9      29.427869       1
# 7043          0.0           0.0         6      29.427869       1
# 10213         0.0           0.0         1      29.427869       1
# 10643         0.0           0.0         9      29.427869       1
# 7028          0.0           0.0         2      29.427869       1
# 10678         0.0           0.0         5      29.427869       1

# %% [markdown]
# ## Sort by lowest officers rate per 1000

# %%
#Sort by lowest officers rate per 1000
dftop10 = dftarget.sort_values(by=['Officers1000'], ascending=True).head(10)
dftop10
# Out:
#                                              Name                    Address1  \
# BankID
# 8974    JPMorgan Chase Bank, National Association  2551 Broadway, 96th Street
# 9917    JPMorgan Chase Bank, National Association      9059 Sutphin Boulevard
# 9912    JPMorgan Chase Bank, National Association       161-10 Jamaica Avenue
# 9911    JPMorgan Chase Bank, National Association           37-67 75th Street
# 9910    JPMorgan Chase Bank, National Association           37-15 82nd Street
# 9909    JPMorgan Chase Bank, National Association  156-33 Cross Bay Boulevard
# 9908    JPMorgan Chase Bank, National Association       8239 153rd Ave, Ste B
# 9902    JPMorgan Chase Bank, National Association    9900 Metropolitan Avenue
# 9901    JPMorgan Chase Bank, National Association     104-17 Queens Boulevard
# 8337    JPMorgan Chase Bank, National Association     3737 Hempstead Turnpike
#
#        Address2             City State    Zip  ClosestPSDistance    Take  \
# BankID
# 8974                    New York    NY  10025           5.868097  240350
# 9917                     Jamaica    NY  11435           5.560809   23801
# 9912                     Jamaica    NY  11432           5.021555   71246
# 9911             Jackson Heights    NY  11372           6.348042  117773
# 9910             Jackson Heights    NY  11372           6.710446  166473
# 9909                Howard Beach    NY  11414           8.219902   88501
# 9908                Howard Beach    NY  11414           8.537553   33226
# 9902                Forest Hills    NY  11375           7.799695   44900
# 9901                Forest Hills    NY  11375           7.399366   96835
# 8337                   Levittown    NY  11756           6.625972   39794
#
#         PDistance  Officers1000  FFLCount  CrimeRate1000  y_pred
# BankID
# 8974     0.113190           0.0         9      20.357615       1
# 9917     0.143919           0.0         4      29.427869       1
# 9912     0.197845           0.0         5      29.427869       1
# 9911     0.065196           0.0        10      29.427869       1
# 9910     0.028955           0.0         9      29.427869       1
# 9909     0.000000           0.0         4      29.427869       1
# 9908     0.000000           0.0         4      29.427869       1
# 9902     0.000000           0.0         5      29.427869       1
# 9901     0.000000           0.0         6      29.427869       1
# 8337     0.037403           0.0        11      29.427869       1
